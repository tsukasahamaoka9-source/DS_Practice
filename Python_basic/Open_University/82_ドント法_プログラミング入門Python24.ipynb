# %% [markdown]
# # 第8章 シミュレーション・WebAPIの利用

# %% [markdown]
#  * 左上の「ファイル」を開いて、「ドライブにコピーを保存」をしてください。
#  * 自分のGoogleドライブに、そのファイルが保存されます。ファイル名は「のコピー」が、最後（右端）についています。それを利用して学習・演習を進めて下さい。

# %% [markdown]
# # 8.2 ドント法

# %% [markdown]
# ドント法とは、比例代表選挙の得票数に応じて議席配分を行う際の計算アルゴリズムの一つである。
#
# 例えば、A, B, C, D 党の各党の得票数が 1200, 660, 1440, 180 であったとする。定数は 6 とする。
#
# * 残り6議席
#   * A:1200, B:660, C:1440, D:180
#   * ここで最も大きい1440の政党Cが１議席目を得る。そして、Cの元の得票数1440を2で割る。
# * 残り5議席
#   * A:1200, B:660, C:720, D:180
#   * ここで最も大きい1200の政党Aが1議席目を得る。そして、Aの元の得票数1200を2で割る。
# * 残り4議席
#   * A:600, B:660, C:720, D:180
#   * ここで最も大きい720の政党Cが2議席目を得る。そして、Cの元の得票数1440を3で割る。
# * 残り3議席
#   * A:600, B:660, C:480, D:180
#   * ここで最も大きい660の政党Bが1議席目を得る。そして、Bの元の得票数660 を2で割る。
# * 残り2議席
#   * A:600, B:330, C:480, D:180
#   * ここで最も大きい600の政党Aが2議席目を得る。そして、Aの元の得票数1200を3で割る。
# * 残り1議席
#   * A:400, B:330, C:480, D:180
#   * ここで最も大きい480の政党Cが3議席目を得る。
# * これで終わり。

# %% [markdown]
# 【プログラム8201】

# %%
# 得票状況と議席数の設定
tokuhyo = [["A", 1200], ["B", 660], ["C", 1440], ["D", 180]]
giseki = 6

# 初期化
tousu = len(tokuhyo) # 党数
hikaku = [0] * tousu # 比較検討リスト
tousenkei = 0 # すでに当選が決まった人数

# 各党に、当選数を末尾に初期化（全党 0 にする）して追加
for kakutou in tokuhyo:
    kakutou.append(0)

# 比較検討リストに、得票数を複写
for m in range(tousu):
    hikaku[m] = tokuhyo[m][1]

# 当選数が議席数を下回っている間、続ける
while tousenkei < giseki:
    print(tokuhyo, hikaku)
    # 比較検討リストの最大を探すために max を 0
    max = 0
    # 比較検討リストの最大 hikaku[maxi] の maxi を探して当選にする
    for i in range(tousu):
        if max < hikaku[i]:
            max = hikaku[i]
            maxi = i
    # 当選が決まったら割り当てる
    tokuhyo[maxi][2] = tokuhyo[maxi][2] + 1
    # 合計を増やす
    tousenkei = tousenkei + 1
    # 比較検討リストを更新する
    hikaku[maxi] = tokuhyo[maxi][1] / (tokuhyo[maxi][2] + 1)

# 結果の表示
print(tokuhyo, hikaku)
# Out:
# [['A', 1200, 0], ['B', 660, 0], ['C', 1440, 0], ['D', 180, 0]] [1200, 660, 1440, 180]
# [['A', 1200, 0], ['B', 660, 0], ['C', 1440, 1], ['D', 180, 0]] [1200, 660, 720.0, 180]
# [['A', 1200, 1], ['B', 660, 0], ['C', 1440, 1], ['D', 180, 0]] [600.0, 660, 720.0, 180]
# [['A', 1200, 1], ['B', 660, 0], ['C', 1440, 2], ['D', 180, 0]] [600.0, 660, 480.0, 180]
# [['A', 1200, 1], ['B', 660, 1], ['C', 1440, 2], ['D', 180, 0]] [600.0, 330.0, 480.0, 180]
# [['A', 1200, 2], ['B', 660, 1], ['C', 1440, 2], ['D', 180, 0]] [400.0, 330.0, 480.0, 180]
# [['A', 1200, 2], ['B', 660, 1], ['C', 1440, 3], ['D', 180, 0]] [400.0, 330.0, 360.0, 180]

# %% [markdown]
# ### 確認問題　（確認問題の正答はありません。授業中に提示します）

# %% [markdown]
# 上記のデータをいろいろ変化させてみて、当選状況についてのシミュレーションを行え。

# %% [markdown]
# ### 研究問題

# %% [markdown]
# 上記のプログラムを利用すると、ある状況でトラブルが発生する。それはどのようなトラブルか。

# %% [markdown]
# ### 研究問題（各自の課題です）

# %% [markdown]
# 選挙に関連して、アダムス方式という計算方法がある。どのような方法か調べ、ドント法との違いなどについて述べよ。また、アダムス方式のプログラムを作成して、計算を行え。

# %% [markdown]
# # 次の教材
#
# 8.3 WebAPIの利用 気象庁
# * https://colab.research.google.com/drive/1raBoPnbESdtWWgtTzMzRtQKaQQK-TT3C
