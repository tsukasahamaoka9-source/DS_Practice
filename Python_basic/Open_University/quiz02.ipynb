# %% [markdown]
# 以下には、クイズが何問か並んでいます。よく読んで、選択肢を1つ定めて、メモをとってください。すべてのクイズの解答が決まったら、このページの最後にあるリンクから正解ページを見て、答え合わせをしてください。このクイズの結果は、成績には関係ありません。
#
# しかし、各回の最後に設置されている小テストは、受験1回目の成績が、全体の成績に反映されます。ですから、小テストの前に、このクイズを使って、しっかり理解しておくとよいです。

# %% [markdown]
# **QUIZ2-1**
#
# 次の選択肢のプログラムを実行して、キーボードから 2 を入力した。**エラーになるもの**を1つ選べ。（実行せずに解答せよ。）

# %%
#①
t = int(input("a?"))
print(t + 1)

# %%
#②
t = input("a?")
print(t + 1)

# %%
#③
t = input("a?")
print(t + "1")

# %%
#④
t = input("a?")
print(int(t) + 1)

# %% [markdown]
# **QUIZ2-2**
#
# 次の選択肢のうち、実行すると**必ずエラーになるもの**を1つ選べ。
#
# ① a = 99
#
# ② 3 + 3 = a
#
# ③ a = b + 1
#
# ④ a = a + 1

# %% [markdown]
# **QUIZ2-3**
#
# 次の選択肢のうち、実行すると**エラーになるもの**を1つ選べ。

# %%
#①
x = (0, 1, 2) * 3
x.append(13)

# %%
#②
ones = [1] * 10
print(ones[2])

# %%
#③
cards = [1] * 12
cards.append(13)

# %%
#④
wanwan = (1,) * 8
print(wanwan[2])

# %% [markdown]
# **QUIZ2-4**
#
# keys = "abcdefgh" とする。次の選択肢のうち、**誤っている**ものを1つ選べ。
#
# ① keys[0:1] は、 "a" である。
#
# ② keys[2:2] は、 空列（長さ0の文字列）である。
#
# ③ keys[0:100] は、 "abcdefgh" である。
#
# ④ keys[10:0] は、 "hgfedcba" である。

# %% [markdown]
# 第2回のクイズの解答（正解）はこちらです。
# https://colab.research.google.com/drive/1rgrQT-ugwp4GQ0sYMi5UpXaGN8LI-BUh
