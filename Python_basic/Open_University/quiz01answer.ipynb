# %% [markdown]
# **クイズの解答（正解）**
#
# 以下に、クイズの正解を示します。クイズは何度回答しても成績には影響がありませんので、小テストを受ける前に繰り返して受けてみて、理解を深めるようにしてください。その後、小テストを受験してください。

# %% [markdown]
# **QUIZ1-1**
#
# 次の選択肢のうち、正しいものを1つ選べ。
#
# ①プログラミングができないと、日常の文書を作成するときも苦労する。
#
# ②人間が書いたプログラムを実行する仕組みを、言語処理系という。
#
# ③この授業の Google Colaboratory の設定では、インデント幅は「20」を指定している。
#
# ④この授業の教材の Google Colaboratory のノートブックを利用する場合は、まず、教材をダウンロードして、自分のパソコンにインストールすることから始める必要がある。
#
# 正解は②です。人間が書いたプログラムを実行する仕組みは、「言語処理系」と呼ばれます。

# %% [markdown]
# **QUIZ1-2**
#
# 次の選択肢のうち、正しいものを1つ選べ。
#
# ①文字列の長さは1以上である。
#
# ②"Makuhari"+"Wakaba" は、 "Makuhari+Wakaba" になる。
#
# ③x = "mojimoji"mojimoji" を実行しようとすると、エラーが出力されて終わる。
#
# ④プログラム中に、* を記せば、その行の、* から右側は実行されない。
#
# 正解は③です。
# x = "mojimoji"mojimoji" を実行しようとすると、2つのダブルクオーテーションマークでダブルクオーテーションマークを挟む記述になっているので、エラーが発生します。

# %%
x = "mojimoji"mojimoji"
# Out:
#   File "<ipython-input-1-6ba1a3909092>", line 1
#     x = "mojimoji"mojimoji"
#                           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# **QUIZ1-3**
#
# 次の選択肢のうち、**誤っているもの**を1つ選べ。
#
# ①x = 2 を実行したあと、 print(type(x)) を実行すると、int が表示される。
#
# ②x = 2.7 を実行したあと、 print(type(x)) を実行すると、float が表示される。
#
# ③x = 2 + 3j を実行したあと、 print(type(x)) を実行すると、complex が表示される。
#
# ④print(int("2") + int("3"))を実行すると、 23 が表示される。
#
# 正解は④です。何が表示されるかは、以下で確認してください。

# %%
x = 2
print(type(x))
# Out:
# <class 'int'>

# %%
x = 2.7
print(type(x))
# Out:
# <class 'float'>

# %%
x = 2 * 3j
print(type(x))
# Out:
# <class 'complex'>

# %%
print(int("2") + int("3"))
# Out:
# 5

# %% [markdown]
# **QUIZ1-4**
#
# 次の選択肢のうち、実行すると**必ずエラーになるもの**を1つ選べ。

# %%
# ①
a = ( 1 +
        2 )

# %%
# ②
b = 1 +\
        2

# %%
# ③
c = "1" \
        + "2"

# %%
# ④
d = "1"
        + "2"

# %% [markdown]
# 正解は④です。プログラムを書いていて、横に長くなったとき、途中で改行を入れることができますが、そのときには、丸括弧で挟むか、改行の直前に \ を置く必要があります。

# %%
# ④
d = "1"
        + "2"
# Out:
#   File "<ipython-input-2-1a86bdb6311e>", line 3
#     + "2"
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# **QUIZ1-5**
#
# 他人の Colaboratory のノートブックをコピーした。そのノートブックは、何処に作られるか。次の選択肢のうち、正しいものを1つ選べ。
#
# ①Googleドライブの「マイドライブ」フォルダの中にある、 「Colab Notebooks」 というフォルダの中
#
# ②Googleドライブの「マイドライブ」フォルダの中にある、 「マイドキュメント」 というフォルダの中
#
# ③Googleドライブの「マイドライブ」フォルダの中にある、 「マイプログラム」 というフォルダの中
#
# ④Googleドライブの「マイドライブ」フォルダの中にある、 「デスクトップ」 というフォルダの中
#
# 正解は①です。なお、 Google Colaboratory では、パソコンのフォルダを原則として利用しません。
