# %% [markdown]
# **クイズの解答（正解）**
#
# 以下に、クイズの正解を示します。クイズは何度回答しても成績には影響がありませんので、小テストを受ける前に繰り返して受けてみて、理解を深めるようにしてください。その後、小テストを受験してください。

# %% [markdown]
# **QUIZ5-1**
#
# 次のプログラムを作成した。

# %%
import matplotlib.pyplot as plt

vx = (1, 2, 3)
vy = (2, 5, 4)

plt.scatter(vx, vy)
plt.show()

# %% [markdown]
# このプログラムに関する説明として正しいものを、次の選択肢から1つ選べ。
#
# ①1行目は、乱数を発生させるライブラリを呼び出している。
#
# ②このプログラムを実行すると、3D描画領域の四角形の中には2つの点が描画される。
#
# ③3行目と4行目を入れ替えると、描かれる点は直線 y=x について線対称の位置に移動する。
#
# ④3行目だけを削除すると、実行エラーが発生する。
#
# 正解は④です。3行目だけを削除すると、タプル vx を定めている部分がなくなり、6行目で vx を参照しようとしてエラーになります。（なお、削除したあとに動作しないことを確認する際は、Google Colaboratory の右上の RAM ディスク のメニューの「ランタイムを接続解除して削除」を選んでください。）

# %%
import matplotlib.pyplot as plt

# vx = (1, 2, 3) # 3行目削除（コメントアウト）
vy = (2, 5, 4)

plt.scatter(vx, vy)
plt.show()

# %% [markdown]
# **QUIZ5-2**
#
# 次のプログラムを作成した。

# %%
import matplotlib.pyplot as plt
# !pip install japanize-matplotlib
import japanize_matplotlib

htemp = (
    22.4, 22.8, 22.7,
    14.9, 20.9, 24.7,
    22.6, 27.4, 27.9,
    29.1, 16.9, 24.7,
    22.3, 25.6)

plt.hist(htemp, color="red", bins=8, range=(10, 34))
plt.title("2023年5月の千葉市の最高温度の日数")
plt.xlabel("温度")
plt.ylabel("日数")
plt.show()

# %% [markdown]
# このプログラムについての記述で**誤っているもの**を、次の選択肢から1つ選べ。
#
# ①1行目から3行目は、グラフを書き、その中に漢字を利用するために必要である。
#
# ②5行目から10行目は、14個のデータを利用したタプルを定義している。
#
# ③このプログラムを実行して描かれたヒストグラムの色は赤である。
#
# ④12行目の「bins=8」を「bins=12」にすると、階級幅は 24 になる。
#
# 正解は④です。この場合の階級幅は、 (34-10) / 12 = 2 となります。

# %% [markdown]
# **QUIZ5-3**
#
# 次のプログラムを作成した。

# %%
import matplotlib.pyplot as plt

history = (82, 75, 40, 73, 65, 100, 78, 99, 71, 83)
informatics = (30, 90, 20, 22, 45, 81, 66, 78, 45, 100)

kamokumei = (history, informatics)
kamokumei_en = ("history", "informatics")
fig, ax = plt.subplots()

bp = ax.boxplot(kamokumei)
ax.set_xticklabels(kamokumei_en)

plt.title('score')
plt.grid()
plt.show()

# %% [markdown]
# このプログラムについての記述で正しいものを、次の選択肢から1つ選べ。
#
# ①3行目から4行目の history, informatics の2つの代入命令の右辺を、タプルではなくリストにすると、実行エラーになる。
#
# ②3行目と4行目を入れ替えても、同じ結果を得ることができる。
#
# ③6行目と7行目を入れ替えると、表示結果は異なるものとなる。
#
# ④13行目の 'score' の表示は、このグラフに得点を併記するという意味である。
#
# 正解は②です。表示を決めているのは、10行目の kamokumei であり、それは 6行目で定義されたタプルです。なので、3行目と4行目を入れ替えても、結果は同じです。

# %% [markdown]
# **QUIZ5-4**
#
# 次のデータを利用して、分析を行った。
#
# データ
# ```
# # 数学の点数
# math = (77, 92, 12, 27, 84, 95, 28, 60, 38, 6)
# # 英語の点数
# english = (82, 75, 40, 73, 65, 100, 78, 99, 71, 83)
# # 情報の点数
# informatics = (90, 90, 20, 22, 25, 81, 66, 78, 45, 100)
# ```
#
# 求めた相関係数行列を次に示す。
# ```
#       数学        英語        情報
# 数学  1.000000  0.420220  0.281329
# 英語  0.420220  1.000000  0.702941
# 情報  0.281329  0.702941  1.000000
# ```
# この結果からわかることとして、正しいことを下の選択肢から1つ選べ。
#
# ①これは、30人の成績データを利用した分析である。
#
# ②英語と情報の得点の相関よりも、数学と情報の得点の相関の方が低い。
#
# ③英語と数学の得点の相関よりも、情報と数学の得点の相関の方が高い。
#
# ④数学と英語の得点の相関よりも、数学と情報の得点の相関の方が高い。
#
# 正解は②です。なお、③と④は、紛らわしいですが、実は同じことを述べています。「AとBの相関係数」と「BとAの相関係数」は同じです。
